# %% [markdown]
# <a href="https://colab.research.google.com/github/dipakpatil2001/D-SCIENCE/blob/main/Air_Bnb_DP_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**D
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project we are going to perform Exploratory Data Analysis on AirBnb Booking Analysis dataset. The dataset consists of 1 table. The table called ‘
# Airbnb NYC 2019.csv’.
#
# ***This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.***
#
# Steps involved in this analysis are as follows:
#
# Import the data
# Check the data Cleaning the data Analyzing the data Visualizing the data *Conclusion

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [project link](https://github.com/dipakpatil2001/D-SCIENCE/blob/main/Air_Bnb_DP_.ipynb)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Since 2008, guests and hosts have used Airbnb to expand on traveling
# possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Goal behind this project is to find answers for the following questions:**
#
# *   What can we learn about different hosts and areas?
# *   What can we learn from predictions? (ex: locations, prices, reviews, etc)
# *   Which hosts are the busiest and why?
# *   Is there any noticeable difference of traffic among different areas and
# *  what could be the reason for it?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Airbnb NYC 2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df1.tail(5)
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1.duplicated().value_counts()
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(df1)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# for object type variables
for i in df1.select_dtypes(include="object").columns:
  print(i)
  print(df1[i].unique())
# Out:
# name
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# host_name
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# neighbourhood_group
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# neighbourhood
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
# ...

# %%
# Now Check Unique Values for numeric (float) variable.
for i in df1.select_dtypes(include='float64').columns:
  print(i)
  print(df1[i].unique())
# Out:
# latitude
# [40.64749 40.75362 40.80902 ... 40.80953 40.70184 40.81475]
# longitude
# [-73.97237 -73.98377 -73.9419  ... -73.87727 -73.93614 -73.80844]
# reviews_per_month
# [2.100e-01 3.800e-01       nan 4.640e+00 1.000e-01 5.900e-01 4.000e-01
#  3.470e+00 9.900e-01 1.330e+00 4.300e-01 1.500e+00 1.340e+00 9.100e-01
#  2.200e-01 1.200e+00 1.720e+00 2.120e+00 4.440e+00 7.000e-02 1.090e+00
#  3.700e-01 6.100e-01 7.300e-01 1.370e+00 4.900e-01 1.110e+00 2.400e-01
#  2.040e+00 1.420e+00 1.650e+00 2.370e+00 6.600e-01 1.410e+00 1.960e+00
#  1.810e+00 2.080e+00 3.900e-01 2.300e-01 6.900e-01 8.400e-01 2.250e+00
#  5.200e-01 1.160e+00 1.010e+00 6.300e-01 7.000e-01 2.820e+00 9.000e-01
#  1.700e-01 2.490e+00 1.190e+00 3.000e-01 1.200e-01 5.700e-01 1.600e-01
#  4.720e+00 1.400e+00 1.260e+00 1.640e+00 1.600e+00 9.200e-01 2.000e-01
#  1.280e+00 5.400e-01 6.200e-01 1.500e-01 5.300e-01 1.730e+00 5.000e-02
#  1.540e+00 2.800e-01 3.400e+00 1.570e+00 1.050e+00 7.100e-01 1.100e-01
# ...

# %%
# Now Check Unique Values for numeric (integer) variable.
for i in df1.select_dtypes(include='int64').columns:
  print(i)
  print(df1[i].unique())
# Out:
# id
# [    2539     2595     3647 ... 36485431 36485609 36487245]
# host_id
# [     2787      2845      4632 ... 274321313  23492952  68119814]
# price
# [  149   225   150    89    80   200    60    79   135    85   120   140
#    215    99   190   299   130   110    44   180    50    52    55    70
#     35    40    68   115   151   228   144    69    49   375   250   275
#    230    51    65   105    95   145   285    94   800   131    98   100
#    125   175   500   101   220    59   350   199   325   235   170   400
#     75    90   185    77    76   160   195   156   219   475   165   196
#     83   123   265   249   121    45    71    64   159   189   239   305
#    155    92    36    37   205    39   390   129   212   124   122   109
#    575   229   169   113   179   349   139   650    67   599   211   290
#     87   395   260    97   132   141   495   259    96   295   451   300
#     42   255    72    88   450   198    46    33   106    91  2000   429
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#checking distribution of numerical data
# list of numerical variables
numerical_features = [feature for feature in df1.columns if (df1[feature].dtypes != 'O')]
print('Total number of numerical variables: ', len(numerical_features))

df1[numerical_features].head(5)   # visualise the numerical variables
# Out:
# Total number of numerical variables:  10
#      id  host_id  latitude  longitude  price  minimum_nights  \
# 0  2539     2787  40.64749  -73.97237    149               1
# 1  2595     2845  40.75362  -73.98377    225               1
# 2  3647     4632  40.80902  -73.94190    150               3
# 3  3831     4869  40.68514  -73.95976     89               1
# 4  5022     7192  40.79851  -73.94399     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0                NaN                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365
# 0               365
# 1               355
# 2               365
# 3               194
# ...

# %%
#plot univariate distribution of continues observations
plt.figure(figsize=(20,60), facecolor='yellow')
plotnumber =1
for i in numerical_features:         #using for-loop to plot the grap
    ax = plt.subplot(18,5,plotnumber)
    sns.histplot(df1[i])            #ploting distribution-plot to observe the distribution
    plt.xlabel(i)
    plotnumber+=1
plt.show()

# %%
#box plot to observe distribution of data
plt.figure(figsize=(25,25))     #fig size setting
plt.subplot(3,3,1)
sns.boxplot(x='price',data=df1)
plt.title("plot 1")
plt.subplot(3,3,2)
sns.boxplot(x='minimum_nights',data=df1)
plt.title("plot no 2")
plt.subplot(3,3,3)
sns.boxplot(x='number_of_reviews',data=df1)
plt.subplot(3,3,4)
plt.title("plot no 3")
sns.boxplot(x='calculated_host_listings_count',data=df1)
plt.subplot(3,3,5)
plt.title("plot no 4")
sns.boxplot(x='availability_365',data=df1)
# Out:
# <Axes: title={'center': 'plot no 4'}, xlabel='availability_365'>

# %%
for i in numerical_features:         #using for loop
 print(i,"skewness ",df1[i].skew())   #using skew function to see the skewness values
# Out:
# id skewness  -0.090257375459433
# host_id skewness  1.2062139240662195
# latitude skewness  0.2371665584936874
# longitude skewness  1.2842102085169105
# price skewness  19.118938995046033
# minimum_nights skewness  21.827274529642168
# number_of_reviews skewness  3.690634571595388
# reviews_per_month skewness  3.13018853561771
# calculated_host_listings_count skewness  7.933173899690269
# availability_365 skewness  0.7634075771134318

# %%
df1.describe(include = 'all')  #describing all data using include= all
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
#filling null values for numeric feature
for i in numerical_features:
  df1[i].fillna(df1[i].median(), inplace=True)       #using fillna function to fill null values
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#filling null values for v=catagorical data
df1["name"].fillna(df1["name"].mode()[0], inplace=True)         #replacing null values by mode using fillna function
df1["host_name"].fillna(df1["host_name"].mode()[0], inplace=True)
df1["last_review"].fillna(df1["last_review"].mode()[0], inplace=True)

# %%
df1.isnull().sum()                  #verifying weather null values are replaced or not
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# Visualizing the missing values after data cleaning and filling null values
msno.bar(df1) #ploting bar plot using missingno library
# Out:
# <Axes: >

# %% [markdown]
# **Summary:**
#
# we have replaced few charaters from data set so we can change their data type droped few columns as we were not going to use them in analysis also they were having more then 50% null values an rest of the columns which had null values are been replaced so now we are ready for data Vizualization.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# **Bivatiate analysis:**
#
# Bivariate analysis refers to the analysis of two variables to determine relationships between them

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1 visualization code
plt.figure(figsize=(10,10))
plt.pie(df1.room_type.value_counts(), labels=df1.room_type.value_counts().index, autopct='%1.2f%%')
my_circle = plt.Circle( (0,0), 0.50, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('% of room type share in bookings', fontsize = 25)
plt.show()

# %%
df1['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %% [markdown]
# **We found that Entire home/apt is the highest number of room types overall**

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
df1['minimum_nights'].value_counts().plot.bar(figsize=(20,8), color = 'k' )  #ploting bar plot
plt.xlabel('Minimum nights',fontsize = 15 )             #labeling x axis
plt.ylabel('Number of hotels', fontsize = 15)              #labeling y axis
plt.title('Minimum nights booking of hotels', fontsize = 20)  #giving title
plt.legend();

# %%
df1['minimum_nights'].value_counts().head(20)
# Out:
# 1     12720
# 2     11696
# 3      7999
# 30     3760
# 4      3303
# 5      3034
# 7      2058
# 6       752
# 14      562
# 10      483
# 29      340
# 15      279
# 20      223
# 28      203
# 31      201
# 21      135
# 8       130
# 60      106
# 90      104
# 12       91
# Name: minimum_nights, dtype: int64

# %% [markdown]
# **by seeing above visualization we can say that the maximum number of people book room for 1 night followed by 2,3 nights and then for a complete month.**

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
r1 = df1
cou=r1.groupby("room_type")['room_type'].count()
plt.rcParams['figure.figsize'] = (10, 10)    # setting up the figure size of our data so all the things gets easily visible
axx=sns.barplot(x=cou, y=cou.index, data=df1)
axx.set(xlabel='number of bookings', ylabel='room_types')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cou
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
df1.corr()
# Out:
# <ipython-input-54-186776c1236b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588290 -0.003125   0.090908
# host_id                         0.588290  1.000000  0.020224   0.127055
# latitude                       -0.003125  0.020224  1.000000   0.084788
# longitude                       0.090908  0.127055  0.084788   1.000000
# price                           0.010619  0.015309  0.033939  -0.150019
# minimum_nights                 -0.013224 -0.017364  0.024869  -0.062747
# number_of_reviews              -0.319760 -0.140106 -0.015389   0.059094
# reviews_per_month               0.220804  0.236499 -0.014078   0.137153
# ...

# %%
#plot a heatmap to see the correlaton between the columns
cor_mat=df1.corr()
fig = plt.figure(figsize=(15,7))
sns.heatmap(cor_mat,annot=True)
# Out:
# <ipython-input-56-8fc723cafc6f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_mat=df1.corr()
# <Axes: >

# %% [markdown]
# **We have seen all the correlation between different variables**

# %% [markdown]
# as we wanted to see the correlation of numeric data we used heat map
#
# Clearly, we saw that reviews per month and the number of reviews are more correlated and the value is 0.57. Price and minimum nights are also more correlated with value of 0.47.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
areas_review=df1.groupby(['name','neighbourhood_group','price','minimum_nights'])['number_of_reviews'].count().reset_index()
sorting_price=areas_review.sort_values('price',ascending=False)
sorting_price
# Out:
#                                                     name neighbourhood_group  \
# 1112                                 1-BR Lincoln Center           Manhattan
# 27239    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 20219                Furnished room in Astoria apartment              Queens
# 41061                                 Spanish Harlem Apt           Manhattan
# 2224   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# ...                                                  ...                 ...
# 48236                              the best you can find           Manhattan
# 48410      ★Hostel Style Room | Ideal Traveling Buddies★               Bronx
# 27935    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)            Brooklyn
# 43839                    Sunny, Quiet Room in Greenpoint            Brooklyn
# 40517  Spacious comfortable master bedroom with nice ...            Brooklyn
#
# ...

# %%
area=sorting_price['neighbourhood_group']
price=sorting_price['price']

plt.bar(area,price)
plt.rcParams['figure.figsize'] = (10,10)
plt.title('table')
plt.xlabel('area')
plt.ylabel('price')
plt.legend
plt.show()

# %% [markdown]
# **By seeing above visualization we can say that Manhattan, Brooklyn, Queens area, Stated Island, Bronx respectivly are areas where prices are too high.**

# %% [markdown]
# #### Chart - 6

# %%
price_area = df1.groupby(['price'])['number_of_reviews'].max().reset_index()
price_area.head(10)
# Out:
#    price  number_of_reviews
# 0      0                 95
# 1     10                 93
# 2     11                113
# 3     12                  8
# 4     13                  9
# 5     15                 19
# 6     16                 43
# 7     18                  1
# 8     19                 76
# 9     20                116

# %%
# Chart - 6 visualization code
price_list = price_area['price']
review = price_area['number_of_reviews']
fig =plt.figure(figsize =(10,5))

plt.scatter(price_list, review)
plt.xlabel('Price')
plt.ylabel('Number of reviews')
plt.title('Number of Reviews VS Price')
plt.show()

# %% [markdown]
# **From above visualization we can imply  that most number of people like to stay in less price and their reviews are higher in those areas**

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# getting number of unique host names
lst =df1['host_name'].unique()
len(lst)
# Out:
# 11452

# %%
#extracting most valuable host names
busiest_host=df1.groupby(["host_name","neighbourhood","room_type"])["minimum_nights"].count().reset_index()
valuable_host=busiest_host.sort_values("minimum_nights",ascending=False).head(7)
print(valuable_host)
# Out:
#           host_name       neighbourhood        room_type  minimum_nights
# 28586  Sonder (NYC)  Financial District  Entire home/apt             210
# 31202          Vida          Greenpoint  Entire home/apt              52
# 28581        Sonder  Financial District  Entire home/apt              51
# 28590  Sonder (NYC)         Murray Hill  Entire home/apt              50
# 25608    Red Awning             Midtown  Entire home/apt              49
# 28811       Stanley         Murray Hill  Entire home/apt              49
# 15001          John      Hell's Kitchen     Private room              47

# %%
#visualizing data in bar plot
main_hosts=valuable_host["host_name"]
min_nigh=valuable_host["minimum_nights"]
plt.bar(main_hosts,min_nigh, color='y')
plt.title("biggest hosts")
plt.xlabel("host names")
plt.ylabel("minimum nights")
plt.show()

# %% [markdown]
# # ****The highest host are:****
#
# #1.sonder(NYC)
#
# #2.Vida
#
# #3.Sonder

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.rcParams['figure.figsize'] = (8, 5)
ax= sns.countplot(y='room_type',hue='neighbourhood_group',data=df1,palette='bright')

total = len(df1['room_type'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.title('Count of each room types in NYC')
plt.xlabel('Rooms')
plt.xticks(rotation=90)
plt.ylabel('Room Counts')

plt.show()

# %% [markdown]
# **Manhattan has more listed properties with Entire home/apt around 27% of total listed properties followed by Brooklyn with around 19.6%.**
#
#
# **Private rooms are more in Brooklyn as in 20.7% of the total listed properties followed by Manhattan with 16.3% of them. While 6.9% of private rooms are from Queens.**
#
#
# **We can infer that Brooklyn,Queens,Bronx has more private room types while Manhattan which has the highest no of listings in entire NYC has more Entire home/apt room types.**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
